# %% [markdown]
# # Check XDF files
# We need to verify that correct markers are streamed by the program

# %%
import pyxdf
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/media/l.darmet/DONNEES1/l.darmet/data/FlickerOnTop.xdf'
data, header = pyxdf.load_xdf(path)
# Out:
# Stream 1: Calculated effective sampling rate 32.1397 Hz is different from specified rate 0.1000 Hz.

# %%
for stream in data:
    y = stream['time_series']

    if isinstance(y, list):
        # list of strings, draw one vertical line for each marker
        for timestamp, marker in zip(stream['time_stamps'], y):
            plt.axvline(x=timestamp)
            print(f'Marker "{marker[0]}" @ {timestamp:.2f}s')
    elif isinstance(y, np.ndarray):
        # numeric data, draw as lines
        plt.plot(stream['time_stamps'], y)
    else:
        raise RuntimeError('Unknown stream format')
# Out:
# Marker "2" @ 6248.80s
# Marker "2" @ 6248.82s
# Marker "2" @ 6248.83s
# Marker "2" @ 6248.85s
# Marker "2" @ 6248.87s
# Marker "2" @ 6248.88s
# Marker "2" @ 6248.90s
# Marker "2" @ 6248.92s
# Marker "2" @ 6248.93s
# Marker "2" @ 6248.95s
# Marker "2" @ 6248.97s
# Marker "2" @ 6248.98s
# Marker "2" @ 6249.00s
# Marker "2" @ 6249.02s
# Marker "2" @ 6249.03s
# Marker "2" @ 6249.05s
# Marker "2" @ 6249.07s
# Marker "2" @ 6249.08s
# Marker "2" @ 6249.10s
# Marker "2" @ 6249.12s
# Marker "2" @ 6249.13s
# Marker "2" @ 6249.15s
# Marker "2" @ 6249.17s
# Marker "2" @ 6249.18s
# Marker "2" @ 6249.20s
# Marker "2" @ 6249.22s
# Marker "2" @ 6249.23s
# Marker "2" @ 6249.25s
# Marker "2" @ 6249.27s
# Marker "2" @ 6249.28s
# Marker "2" @ 6249.30s
# Marker "2" @ 6249.32s
# Marker "2" @ 6249.33s
# Marker "2" @ 6249.35s
# Marker "2" @ 6249.37s
# Marker "2" @ 6249.38s
# Marker "2" @ 6249.40s
# Marker "2" @ 6249.42s
# Marker "2" @ 6249.43s
# Marker "2" @ 6249.45s
# Marker "2" @ 6249.47s
# Marker "2" @ 6249.48s
# Marker "2" @ 6249.50s
# Marker "2" @ 6249.52s
# Marker "2" @ 6249.53s
# Marker "2" @ 6249.55s
# Marker "2" @ 6249.57s
# Marker "2" @ 6249.58s
# Marker "2" @ 6249.60s
# Marker "2" @ 6249.62s
# Marker "2" @ 6249.63s
# Marker "2" @ 6249.65s
# Marker "2" @ 6249.67s
# Marker "2" @ 6249.68s
# Marker "2" @ 6249.70s
# Marker "2" @ 6249.72s
# Marker "2" @ 6249.73s
# Marker "2" @ 6249.75s
# Marker "2" @ 6249.77s
# Marker "2" @ 6249.78s
# Marker "2" @ 6249.80s
# Marker "2" @ 6249.82s
# Marker "2" @ 6249.83s
# Marker "2" @ 6249.85s
# Marker "2" @ 6249.87s
# Marker "2" @ 6249.88s
# Marker "2" @ 6249.90s
# Marker "2" @ 6249.92s
# Marker "2" @ 6249.93s
# Marker "2" @ 6249.95s
# Marker "2" @ 6249.97s
# Marker "2" @ 6249.98s
# Marker "2" @ 6250.00s
# Marker "2" @ 6250.02s
# Marker "2" @ 6250.03s
# Marker "2" @ 6250.05s
# Marker "2" @ 6250.07s
# Marker "2" @ 6250.08s
# Marker "2" @ 6250.10s
# Marker "2" @ 6250.12s
# Marker "2" @ 6250.13s
# Marker "2" @ 6250.15s
# Marker "2" @ 6250.17s
# Marker "2" @ 6250.18s
# Marker "2" @ 6250.20s
# Marker "2" @ 6250.22s
# Marker "2" @ 6250.23s
# Marker "2" @ 6250.25s
# Marker "2" @ 6250.27s
# Marker "2" @ 6250.28s
# Marker "2" @ 6250.30s
# Marker "2" @ 6250.32s
# Marker "2" @ 6250.33s
# Marker "2" @ 6250.35s
# Marker "2" @ 6250.37s
# Marker "2" @ 6250.38s
# Marker "2" @ 6250.40s
# Marker "2" @ 6250.42s
# Marker "2" @ 6250.43s
# Marker "2" @ 6250.45s
# Marker "2" @ 6250.47s
# Marker "2" @ 6250.48s
# Marker "2" @ 6250.50s
# Marker "2" @ 6250.52s
# Marker "2" @ 6250.53s
# Marker "2" @ 6250.55s
# Marker "2" @ 6250.57s
# Marker "2" @ 6250.58s
# Marker "2" @ 6250.60s
# Marker "2" @ 6250.62s
# Marker "2" @ 6250.63s
# Marker "2" @ 6250.65s
# Marker "2" @ 6250.67s
# Marker "2" @ 6250.68s
# Marker "2" @ 6250.70s
# Marker "2" @ 6250.72s
# Marker "2" @ 6250.73s
# Marker "2" @ 6250.75s
# Marker "2" @ 6250.77s
# Marker "2" @ 6250.78s
# Marker "2" @ 6250.80s
# Marker "2" @ 6250.82s
# Marker "2" @ 6250.83s
# Marker "2" @ 6250.85s
# Marker "2" @ 6250.87s
# Marker "2" @ 6250.88s
# Marker "2" @ 6250.90s
# Marker "2" @ 6250.92s
# Marker "2" @ 6250.93s
# Marker "2" @ 6250.95s
# Marker "2" @ 6250.97s
# Marker "2" @ 6250.98s
# Marker "2" @ 6251.00s
# Marker "2" @ 6251.02s
# Marker "2" @ 6251.03s
# Marker "2" @ 6251.05s
# Marker "2" @ 6251.07s
# Marker "2" @ 6251.08s
# Marker "2" @ 6251.10s
# Marker "2" @ 6251.12s
# Marker "2" @ 6251.13s
# Marker "2" @ 6251.15s
# Marker "2" @ 6251.17s
# Marker "2" @ 6251.18s
# Marker "2" @ 6251.20s
# Marker "2" @ 6251.22s
# Marker "2" @ 6251.23s
# Marker "2" @ 6251.25s
# Marker "2" @ 6251.27s
# Marker "2" @ 6251.28s
# Marker "2" @ 6251.30s
# Marker "2" @ 6251.32s
# Marker "2" @ 6251.33s
# Marker "2" @ 6251.35s
# Marker "2" @ 6251.37s
# Marker "2" @ 6251.38s
# Marker "2" @ 6251.40s
# Marker "2" @ 6251.42s
# Marker "2" @ 6251.43s
# Marker "2" @ 6251.45s
# Marker "2" @ 6251.47s
# Marker "2" @ 6251.48s
# Marker "2" @ 6251.50s
# Marker "2" @ 6251.52s
# Marker "2" @ 6251.53s
# Marker "2" @ 6251.55s
# Marker "2" @ 6251.57s
# Marker "2" @ 6251.58s
# Marker "2" @ 6251.60s
# Marker "2" @ 6251.62s
# Marker "2" @ 6251.63s
# Marker "2" @ 6251.65s
# Marker "2" @ 6251.67s
# Marker "2" @ 6251.68s
# Marker "2" @ 6251.70s
# Marker "2" @ 6251.72s
# Marker "2" @ 6251.73s
# Marker "2" @ 6251.75s
# Marker "2" @ 6251.77s
# Marker "2" @ 6251.78s
# Marker "2" @ 6251.80s
# Marker "2" @ 6251.82s
# Marker "2" @ 6251.83s
# Marker "2" @ 6251.85s
# Marker "2" @ 6251.87s
# Marker "2" @ 6251.88s
# Marker "2" @ 6251.90s
# Marker "2" @ 6251.92s
# Marker "2" @ 6251.93s
# Marker "2" @ 6251.95s
# Marker "2" @ 6251.97s
# Marker "2" @ 6251.98s
# Marker "2" @ 6252.00s
# Marker "2" @ 6252.02s
# Marker "2" @ 6252.03s
# Marker "2" @ 6252.05s
# Marker "2" @ 6252.07s
# Marker "2" @ 6252.08s
# Marker "2" @ 6252.10s
# Marker "2" @ 6252.12s
# Marker "2" @ 6252.13s
# Marker "2" @ 6252.15s
# Marker "2" @ 6252.17s
# Marker "2" @ 6252.18s
# Marker "2" @ 6252.20s
# Marker "2" @ 6252.22s
# Marker "2" @ 6252.23s
# Marker "2" @ 6252.25s
# Marker "2" @ 6252.27s
# Marker "2" @ 6252.28s
# Marker "2" @ 6252.30s
# Marker "2" @ 6252.32s
# Marker "2" @ 6252.33s
# Marker "2" @ 6252.35s
# Marker "2" @ 6252.37s
# Marker "2" @ 6252.38s
# Marker "2" @ 6252.40s
# Marker "2" @ 6252.42s
# Marker "2" @ 6252.43s
# Marker "2" @ 6252.45s
# Marker "2" @ 6252.47s
# Marker "2" @ 6252.48s
# Marker "2" @ 6252.50s
# Marker "2" @ 6252.52s
# Marker "2" @ 6252.53s
# Marker "2" @ 6252.55s
# Marker "2" @ 6252.57s
# Marker "2" @ 6252.58s
# Marker "2" @ 6252.60s
# Marker "2" @ 6252.62s
# Marker "2" @ 6252.63s
# Marker "2" @ 6252.65s
# Marker "2" @ 6252.67s
# Marker "2" @ 6252.68s
# Marker "2" @ 6252.70s
# Marker "2" @ 6252.72s
# Marker "2" @ 6252.73s
# Marker "2" @ 6252.75s
# Marker "2" @ 6252.77s
# Marker "2" @ 6252.78s
# Marker "2" @ 6252.80s
# Marker "2" @ 6252.82s
# Marker "2" @ 6252.83s
# Marker "2" @ 6252.85s
# Marker "2" @ 6252.87s
# Marker "2" @ 6252.88s
# Marker "2" @ 6252.90s
# Marker "2" @ 6252.92s
# Marker "2" @ 6252.93s
# Marker "2" @ 6252.95s
# Marker "2" @ 6252.97s
# Marker "2" @ 6252.98s
# Marker "2" @ 6253.00s
# Marker "2" @ 6253.02s
# Marker "2" @ 6253.03s
# Marker "2" @ 6253.05s
# Marker "2" @ 6253.07s
# Marker "2" @ 6253.08s
# Marker "2" @ 6253.10s
# Marker "2" @ 6253.12s
# Marker "2" @ 6253.13s
# Marker "2" @ 6253.15s
# Marker "2" @ 6253.17s
# Marker "2" @ 6253.18s
# Marker "2" @ 6253.20s
# Marker "2" @ 6253.22s
# Marker "2" @ 6253.23s
# Marker "2" @ 6253.25s
# Marker "2" @ 6253.27s
# Marker "2" @ 6253.28s
# Marker "2" @ 6253.30s
# Marker "2" @ 6253.32s
# Marker "2" @ 6253.33s
# Marker "2" @ 6253.35s
# Marker "2" @ 6253.37s
# Marker "2" @ 6253.38s
# Marker "2" @ 6253.40s
# Marker "2" @ 6253.42s
# Marker "2" @ 6253.43s
# Marker "2" @ 6253.45s
# Marker "2" @ 6253.47s
# Marker "2" @ 6253.48s
# Marker "2" @ 6253.50s
# Marker "2" @ 6253.52s
# Marker "2" @ 6253.53s
# Marker "2" @ 6253.55s
# Marker "2" @ 6253.57s
# Marker "2" @ 6253.58s
# Marker "2" @ 6253.60s
# Marker "2" @ 6253.62s
# Marker "2" @ 6253.63s
# Marker "2" @ 6253.65s
# Marker "2" @ 6253.67s
# Marker "2" @ 6253.68s
# Marker "2" @ 6253.70s
# Marker "2" @ 6253.72s
# Marker "2" @ 6253.73s
# Marker "2" @ 6253.75s
# Marker "2" @ 6253.77s
# Marker "2" @ 6253.78s
# Marker "2" @ 6253.80s
# Marker "2" @ 6253.82s
# Marker "2" @ 6253.83s
# Marker "2" @ 6253.85s
# Marker "2" @ 6253.87s
# Marker "2" @ 6253.88s
# Marker "2" @ 6253.90s
# Marker "2" @ 6253.92s
# Marker "2" @ 6253.93s
# Marker "2" @ 6253.95s
# Marker "2" @ 6253.97s
# Marker "2" @ 6253.98s
# Marker "2" @ 6254.00s
# Marker "2" @ 6254.02s
# Marker "2" @ 6254.03s
# Marker "2" @ 6254.05s
# Marker "2" @ 6254.07s
# Marker "2" @ 6254.08s
# Marker "2" @ 6254.10s
# Marker "2" @ 6254.12s
# Marker "2" @ 6254.13s
# Marker "2" @ 6254.15s
# Marker "2" @ 6254.17s
# Marker "2" @ 6254.18s
# Marker "2" @ 6254.20s
# Marker "2" @ 6254.22s
# Marker "2" @ 6254.23s
# Marker "2" @ 6254.25s
# Marker "2" @ 6254.27s
# Marker "2" @ 6254.28s
# Marker "2" @ 6254.30s
# Marker "2" @ 6254.32s
# Marker "2" @ 6254.33s
# Marker "2" @ 6254.35s
# Marker "2" @ 6254.37s
# Marker "2" @ 6254.38s
# Marker "2" @ 6254.40s
# Marker "2" @ 6254.42s
# Marker "2" @ 6254.43s
# Marker "2" @ 6254.45s
# Marker "2" @ 6254.47s
# Marker "2" @ 6254.48s
# Marker "2" @ 6254.50s
# Marker "2" @ 6254.52s
# Marker "2" @ 6254.53s
# Marker "2" @ 6254.55s
# Marker "2" @ 6254.57s
# Marker "2" @ 6254.58s
# Marker "2" @ 6254.60s
# Marker "2" @ 6254.62s
# Marker "2" @ 6254.63s
# Marker "2" @ 6254.65s
# Marker "2" @ 6254.67s
# Marker "2" @ 6254.68s
# Marker "2" @ 6254.70s
# Marker "2" @ 6254.72s
# Marker "2" @ 6254.73s
# Marker "2" @ 6254.75s
# Marker "2" @ 6254.77s
# Marker "2" @ 6254.78s
# Marker "2" @ 6254.80s
# Marker "2" @ 6254.82s
# Marker "2" @ 6254.83s
# Marker "2" @ 6254.85s
# Marker "2" @ 6254.87s
# Marker "2" @ 6254.88s
# Marker "2" @ 6254.90s
# Marker "2" @ 6254.92s
# Marker "2" @ 6254.93s
# Marker "2" @ 6254.95s
# Marker "2" @ 6254.97s
# Marker "2" @ 6254.98s
# Marker "2" @ 6255.00s
# Marker "2" @ 6255.02s
# Marker "2" @ 6255.03s
# Marker "2" @ 6255.05s
# Marker "2" @ 6255.07s
# Marker "2" @ 6255.08s
# Marker "2" @ 6255.10s
# Marker "2" @ 6255.12s
# Marker "2" @ 6255.13s
# Marker "2" @ 6255.15s
# Marker "2" @ 6255.17s
# Marker "2" @ 6255.18s
# Marker "2" @ 6255.20s
# Marker "2" @ 6255.22s
# Marker "2" @ 6255.23s
# Marker "2" @ 6255.25s
# Marker "2" @ 6255.27s
# Marker "2" @ 6255.28s
# Marker "2" @ 6255.30s
# Marker "2" @ 6255.32s
# Marker "2" @ 6255.33s
# Marker "2" @ 6255.35s
# Marker "2" @ 6255.37s
# Marker "2" @ 6255.38s
# Marker "2" @ 6255.40s
# Marker "2" @ 6255.42s
# Marker "2" @ 6255.43s
# Marker "2" @ 6255.45s
# Marker "2" @ 6255.47s
# Marker "2" @ 6255.48s
# Marker "2" @ 6255.50s
# Marker "2" @ 6255.52s
# Marker "2" @ 6255.53s
# Marker "2" @ 6255.55s
# Marker "2" @ 6255.57s
# Marker "2" @ 6255.58s
# Marker "2" @ 6255.60s
# Marker "2" @ 6255.62s
# Marker "2" @ 6255.63s
# Marker "2" @ 6255.65s
# Marker "2" @ 6255.67s
# Marker "2" @ 6255.68s
# Marker "2" @ 6255.70s
# Marker "2" @ 6255.72s
# Marker "2" @ 6255.73s
# Marker "2" @ 6255.75s
# Marker "2" @ 6255.77s
# Marker "2" @ 6255.78s
# Marker "2" @ 6255.80s
# Marker "2" @ 6255.82s
# Marker "2" @ 6255.83s
# Marker "2" @ 6255.85s
# Marker "2" @ 6255.87s
# Marker "2" @ 6255.88s
# Marker "2" @ 6255.90s
# Marker "2" @ 6255.92s
# Marker "2" @ 6255.93s
# Marker "2" @ 6255.95s
# Marker "2" @ 6255.97s
# Marker "2" @ 6255.98s
# Marker "2" @ 6256.00s
# Marker "2" @ 6256.02s
# Marker "2" @ 6256.03s
# Marker "2" @ 6256.05s
# Marker "2" @ 6256.07s
# Marker "2" @ 6256.08s
# Marker "2" @ 6256.10s
# Marker "2" @ 6256.12s
# Marker "2" @ 6256.13s
# Marker "2" @ 6256.15s
# Marker "2" @ 6256.17s
# Marker "2" @ 6256.18s
# Marker "2" @ 6256.20s
# Marker "2" @ 6256.22s
# Marker "2" @ 6256.23s
# Marker "2" @ 6256.25s
# Marker "2" @ 6256.27s
# Marker "2" @ 6256.28s
# Marker "2" @ 6256.30s
# Marker "2" @ 6256.32s
# Marker "2" @ 6256.33s
# Marker "2" @ 6256.35s
# Marker "2" @ 6256.37s
# Marker "2" @ 6256.38s
# Marker "2" @ 6256.40s
# Marker "2" @ 6256.42s
# Marker "2" @ 6256.43s
# Marker "2" @ 6256.45s
# Marker "2" @ 6256.47s
# Marker "2" @ 6256.48s
# Marker "2" @ 6256.50s
# Marker "2" @ 6256.52s
# Marker "2" @ 6256.53s
# Marker "2" @ 6256.55s
# Marker "2" @ 6256.57s
# Marker "2" @ 6256.58s
# Marker "2" @ 6256.60s
# Marker "2" @ 6256.62s
# Marker "2" @ 6256.63s
# Marker "2" @ 6256.65s
# Marker "2" @ 6256.67s
# Marker "2" @ 6256.68s
# Marker "2" @ 6256.70s
# Marker "2" @ 6256.72s
# Marker "2" @ 6256.73s
# Marker "2" @ 6256.75s
# Marker "2" @ 6256.77s
# Marker "2" @ 6256.78s
# Marker "2" @ 6256.80s
# Marker "2" @ 6256.82s
# Marker "2" @ 6256.83s
# Marker "2" @ 6256.85s
# Marker "2" @ 6256.87s
# Marker "2" @ 6256.88s
# Marker "2" @ 6256.90s
# Marker "2" @ 6256.92s
# Marker "2" @ 6256.93s
# Marker "2" @ 6256.95s
# Marker "2" @ 6256.97s
# Marker "2" @ 6256.98s
# Marker "2" @ 6257.00s
# Marker "2" @ 6257.02s
# Marker "2" @ 6257.03s
# Marker "2" @ 6257.05s
# Marker "2" @ 6257.07s
# Marker "2" @ 6257.08s
# Marker "2" @ 6257.10s
# Marker "2" @ 6257.12s
# Marker "2" @ 6257.13s
# Marker "2" @ 6257.15s
# Marker "2" @ 6257.17s
# Marker "2" @ 6257.18s
# Marker "2" @ 6257.20s
# Marker "2" @ 6257.22s
# Marker "2" @ 6257.23s
# Marker "2" @ 6257.25s
# Marker "2" @ 6257.27s
# Marker "2" @ 6257.28s
# Marker "2" @ 6257.30s
# Marker "2" @ 6257.32s
# Marker "2" @ 6257.33s
# Marker "2" @ 6257.35s
# Marker "2" @ 6257.37s
# Marker "2" @ 6257.38s
# Marker "2" @ 6257.40s
# Marker "2" @ 6257.42s
# Marker "2" @ 6257.43s
# Marker "2" @ 6257.45s
# Marker "2" @ 6257.47s
# Marker "2" @ 6257.48s
# Marker "2" @ 6257.50s
# Marker "2" @ 6257.52s
# Marker "2" @ 6257.53s
# Marker "2" @ 6257.55s
# Marker "2" @ 6257.57s
# Marker "2" @ 6257.58s
# Marker "2" @ 6257.60s
# Marker "2" @ 6257.62s
# Marker "2" @ 6257.63s
# Marker "2" @ 6257.65s
# Marker "2" @ 6257.67s
# Marker "2" @ 6257.68s
# Marker "2" @ 6257.70s
# Marker "2" @ 6257.72s
# Marker "2" @ 6257.73s
# Marker "2" @ 6257.75s
# Marker "2" @ 6257.77s
# Marker "2" @ 6257.78s
# Marker "2" @ 6257.80s
# Marker "2" @ 6257.82s
# Marker "2" @ 6257.83s
# Marker "2" @ 6257.85s
# Marker "2" @ 6257.87s
# Marker "2" @ 6257.88s
# Marker "2" @ 6257.90s
# Marker "2" @ 6257.92s
# Marker "2" @ 6257.93s
# Marker "2" @ 6257.95s
# Marker "2" @ 6257.97s
# Marker "2" @ 6257.98s
# Marker "2" @ 6258.00s
# Marker "2" @ 6258.02s
# Marker "2" @ 6258.03s
# Marker "2" @ 6258.05s
# Marker "2" @ 6258.07s
# Marker "2" @ 6258.08s
# Marker "2" @ 6258.10s
# Marker "2" @ 6258.12s
# Marker "2" @ 6258.13s
# Marker "2" @ 6258.15s
# Marker "2" @ 6258.17s
# Marker "2" @ 6258.18s
# Marker "2" @ 6258.20s
# Marker "2" @ 6258.22s
# Marker "2" @ 6258.23s
# Marker "2" @ 6258.25s
# Marker "2" @ 6258.27s
# Marker "2" @ 6258.28s
# Marker "2" @ 6258.30s
# Marker "2" @ 6258.32s
# Marker "2" @ 6258.33s
# Marker "2" @ 6258.35s
# Marker "2" @ 6258.37s
# Marker "2" @ 6258.38s
# Marker "2" @ 6258.40s
# Marker "2" @ 6258.42s
# Marker "2" @ 6258.43s
# Marker "2" @ 6258.45s
# Marker "2" @ 6258.47s
# Marker "2" @ 6258.48s
# Marker "2" @ 6258.50s
# Marker "2" @ 6258.52s
# Marker "2" @ 6258.53s
# Marker "2" @ 6258.55s
# Marker "2" @ 6258.57s
# Marker "2" @ 6258.58s
# Marker "2" @ 6258.60s
# Marker "2" @ 6258.62s
# Marker "2" @ 6258.63s
# Marker "2" @ 6258.65s
# Marker "2" @ 6258.67s
# Marker "2" @ 6258.68s
# Marker "2" @ 6258.70s
# Marker "2" @ 6258.72s
# Marker "2" @ 6258.73s
# Marker "2" @ 6258.75s
# Marker "2" @ 6258.77s
# Marker "2" @ 6258.78s
# Marker "2" @ 6258.80s
# Marker "2" @ 6258.82s
# Marker "2" @ 6258.83s
# Marker "2" @ 6258.85s
# Marker "2" @ 6258.87s
# Marker "2" @ 6258.88s
# Marker "2" @ 6258.90s
# Marker "2" @ 6258.92s
# Marker "2" @ 6258.93s
# Marker "2" @ 6258.95s
# Marker "2" @ 6258.97s
# Marker "2" @ 6258.98s
# Marker "2" @ 6259.00s
# Marker "2" @ 6259.02s
# Marker "2" @ 6259.03s
# Marker "2" @ 6259.05s
# Marker "2" @ 6259.07s
# Marker "2" @ 6259.08s
# Marker "2" @ 6259.10s
# Marker "2" @ 6259.12s
# Marker "2" @ 6259.13s
# Marker "2" @ 6259.15s
# Marker "2" @ 6259.17s
# Marker "2" @ 6259.18s
# Marker "2" @ 6259.20s
# Marker "2" @ 6259.22s
# Marker "2" @ 6259.23s
# Marker "2" @ 6259.25s
# Marker "2" @ 6259.27s
# Marker "2" @ 6259.28s
# Marker "2" @ 6259.30s
# Marker "2" @ 6259.32s
# Marker "2" @ 6259.33s
# Marker "2" @ 6259.35s
# Marker "2" @ 6259.37s
# Marker "2" @ 6259.38s
# Marker "2" @ 6259.40s
# Marker "2" @ 6259.42s
# Marker "2" @ 6259.43s
# Marker "2" @ 6259.45s
# Marker "2" @ 6259.47s
# Marker "2" @ 6259.48s
# Marker "2" @ 6259.50s
# Marker "2" @ 6259.52s
# Marker "2" @ 6259.53s
# Marker "2" @ 6259.55s
# Marker "2" @ 6259.57s
# Marker "2" @ 6259.58s
# Marker "2" @ 6259.60s
# Marker "2" @ 6259.62s
# Marker "2" @ 6259.63s
# Marker "2" @ 6259.65s
# Marker "2" @ 6259.67s
# Marker "2" @ 6259.68s
# Marker "2" @ 6259.70s
# Marker "2" @ 6259.72s
# Marker "2" @ 6259.73s
# Marker "2" @ 6259.75s
# Marker "2" @ 6259.77s
# Marker "2" @ 6259.78s
# Marker "2" @ 6259.80s
# Marker "2" @ 6259.82s
# Marker "2" @ 6259.83s
# Marker "2" @ 6259.85s
# Marker "2" @ 6259.87s
# Marker "2" @ 6259.88s
# Marker "2" @ 6259.90s
# Marker "2" @ 6259.92s
# Marker "2" @ 6259.93s
# Marker "2" @ 6259.95s
# Marker "2" @ 6259.97s
# Marker "2" @ 6259.98s
# Marker "2" @ 6260.00s
# Marker "2" @ 6260.02s
# Marker "2" @ 6260.03s
# Marker "2" @ 6260.05s
# Marker "2" @ 6260.07s
# Marker "2" @ 6260.08s
# Marker "2" @ 6260.10s
# Marker "2" @ 6260.12s
# Marker "2" @ 6260.13s
# Marker "2" @ 6260.15s
# Marker "2" @ 6260.17s
# Marker "2" @ 6260.18s
# Marker "2" @ 6260.20s
# Marker "2" @ 6260.22s
# Marker "2" @ 6260.23s
# Marker "2" @ 6260.25s
# Marker "2" @ 6260.27s
# Marker "2" @ 6260.28s
# Marker "2" @ 6260.30s
